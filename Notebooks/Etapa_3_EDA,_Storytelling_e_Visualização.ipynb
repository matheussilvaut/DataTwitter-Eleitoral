# %% [markdown]
# ###Etapa 3 - EDA, Storytelling e Visualização

# %%
import pandas as pd
import re

# %%
dataframe_final_candidatos = pd.read_csv("etapa2_dataframe_final_candidatos.csv")

# %%
dataframe_final_candidatos.head()
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-08-01 19:41:42+00:00  1554190656221970439
# 1  2022-08-01 19:41:40+00:00  1554190648038891520
# 2  2022-08-01 19:41:39+00:00  1554190644767342595
# 3  2022-08-01 19:41:36+00:00  1554190630938677251
# 4  2022-08-01 19:41:36+00:00  1554190630837952520
#
#                                                Tweet Candidato
# 0  @PedroRonchi2 Peraí. ....e a dinheirama desvia...      Lula
# 1  @LulaOficial @gioewbank @brunogagliasso Jument...      Lula
# 2  @ECantanhede Enquanto tiver eleitor do Lula e ...      Lula
# 3  @xpinvestimentos O futuro é pra quem não cair ...      Lula
# 4  @LulaOficial Excelência:proponha um bolsa famí...      Lula

# %%
dataframe_final_candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Data_Hora  153 non-null    object
#  1   IdTweet    153 non-null    int64
#  2   Tweet      153 non-null    object
#  3   Candidato  153 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 4.9+ KB

# %%
dataframe_final_candidatos.isnull().sum()
# Out:
# Data_Hora    0
# IdTweet      0
# Tweet        0
# Candidato    0
# dtype: int64

# %%
dataframe_final_candidatos['Tweet_limpo'] = dataframe_final_candidatos['Tweet']

# %%
dataframe_final_candidatos.head()
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-08-01 19:41:42+00:00  1554190656221970439
# 1  2022-08-01 19:41:40+00:00  1554190648038891520
# 2  2022-08-01 19:41:39+00:00  1554190644767342595
# 3  2022-08-01 19:41:36+00:00  1554190630938677251
# 4  2022-08-01 19:41:36+00:00  1554190630837952520
#
#                                                Tweet Candidato  \
# 0  @PedroRonchi2 Peraí. ....e a dinheirama desvia...      Lula
# 1  @LulaOficial @gioewbank @brunogagliasso Jument...      Lula
# 2  @ECantanhede Enquanto tiver eleitor do Lula e ...      Lula
# 3  @xpinvestimentos O futuro é pra quem não cair ...      Lula
# 4  @LulaOficial Excelência:proponha um bolsa famí...      Lula
#
#                                          Tweet_limpo
# 0  @PedroRonchi2 Peraí. ....e a dinheirama desvia...
# 1  @LulaOficial @gioewbank @brunogagliasso Jument...
# 2  @ECantanhede Enquanto tiver eleitor do Lula e ...
# 3  @xpinvestimentos O futuro é pra quem não cair ...
# 4  @LulaOficial Excelência:proponha um bolsa famí...

# %%
def limpeza_do_texto(tweet):
  tweet = tweet.lower()
  tweet = re.sub('\n', '', tweet)
  tweet = re.sub('@[^\s]+', '', tweet)
  tweet = re.sub('\B#\S+', '', tweet)
  tweet = re.sub('https?://\S+|www\.\S+', '', tweet)
  return tweet

# %%
dataframe_final_candidatos['Tweet_limpo'] = dataframe_final_candidatos['Tweet'].apply(lambda i:limpeza_do_texto(i))

# %%
dataframe_final_candidatos.head()
# Out:
#                    Data_Hora              IdTweet  \
# 0  2022-08-01 19:41:42+00:00  1554190656221970439
# 1  2022-08-01 19:41:40+00:00  1554190648038891520
# 2  2022-08-01 19:41:39+00:00  1554190644767342595
# 3  2022-08-01 19:41:36+00:00  1554190630938677251
# 4  2022-08-01 19:41:36+00:00  1554190630837952520
#
#                                                Tweet Candidato  \
# 0  @PedroRonchi2 Peraí. ....e a dinheirama desvia...      Lula
# 1  @LulaOficial @gioewbank @brunogagliasso Jument...      Lula
# 2  @ECantanhede Enquanto tiver eleitor do Lula e ...      Lula
# 3  @xpinvestimentos O futuro é pra quem não cair ...      Lula
# 4  @LulaOficial Excelência:proponha um bolsa famí...      Lula
#
#                                          Tweet_limpo
# 0   peraí. ....e a dinheirama desviada da petrobr...
# 1     jumento você esqueceu de dizer que os insul...
# 2   enquanto tiver eleitor do lula e bobos q comp...
# 3   o futuro é pra quem não cair nas falácias da ...
# 4   excelência:proponha um bolsa família de r$100...

# %%
dataframe_final_candidatos.to_csv('dataframe_final_candidatos_pronto_para_sentimento.csv', sep=',', index=False)
